# %%
##print("Question 1: Reverse the string 'Python Programming'")
langauge="Python Programming"
two_words=langauge[::-1]
print(two_words)
# Out:
# gnimmargorP nohtyP

# %%
##print("\nQuestion 2: Check if 'racecar' is a palindrome")
word='racecar'
if word==word[::-1]:
   print('It is a palindrome')
else:
   print('It is not a palindrome')
# Out:
# It is a palindrome

# %%
##print("\nQuestion 3: Count the number of words in 'Python is a great programming language'")
sentence="Python is a great programming language"
full_sentence=len(sentence)
print(full_sentence)
# Out:
# 38

# %%
##print("\nQuestion 4: Convert 'hello world' to title case")
two_words='hello world'
print(two_words.title())
# Out:
# Hello World

# %%
##print("\nQuestion 5: Find the length of string 'Data Science'")
length='Data Science'
full_length=len(length)
print(full_length)
# Out:
# 12

# %%
##print("\nQuestion 6: Replace all spaces with underscores in 'Machine Learning'")
spaces='Machine Learning'
space=spaces.replace(' ','_')
print(space)
# Out:
# Machine_Learning

# %%
##print("\nQuestion 7: Check if 'python' is in 'Python Programming Language'")
pyth='Python Programming Language'
ret="python"
if ret in pyth:
  print(f"Found the {ret} in the {pyth}")
else:
  print(f"Not found the {ret} in the {pyth}")
# Out:
# Not found the python in the Python Programming Language

# %%
##print("\nQuestion 8: Extract the first 5 characters from 'Artificial Intelligence'")
art='Artificial Intelligence'
print(art[0:5])
# Out:
# Artif

# %%
##print("\nQuestion 9: Convert 'UPPERCASE' to lowercase")
wordss='UPPERCASE'
to_wordss=wordss.lower()
print(to_wordss)
# Out:
# uppercase

# %%
##print("\nQuestion 10: Remove all vowels from 'Computer Science'")
text = "Computer Science"

text = text.replace("a","")
text = text.replace("e","")
text = text.replace("i","")
text = text.replace("o","")
text = text.replace("u","")

print("After removing vowels:", text)
# Out:
# After removing vowels: Cmptr Scnc

# %%
##print("\nQuestion 11: Find the most frequent character in 'mississippi'")
text = "mississippi"
freq = {}

for ch in text:
    freq[ch] = freq.get(ch, 0) + 1

most_frequent = max(freq, key=freq.get)
print("Most frequent character:", most_frequent)
# Out:
# Most frequent character: i

# %%
##print("\nQuestion 12: Check if two strings are anagrams: 'listen' and 'silent'")
text1= "listen"
text2="silent"
if sorted(text1)==sorted(text2):
  print("the two strings are anagrams")
else:
    print("the two strings are not anagrams")
# Out:
# the two strings are anagrams

# %%
##print("\nQuestion 13: Capitalize first letter of each word in 'python programming language'")
capital='python programming language'
print(capital.title())
# Out:
# Python Programming Language

# %%
##print("\nQuestion 14: Count consonants in 'Hello World'")
text="Hello World"
count=0
for i in text:
  if i.isalpha() and i not in 'aeiouAEIOU':
    count += 1
print(count)
# Out:
# 7

# %%
##print("\nQuestion 15: Find the longest word in 'Python is a programming language'")
sentence = "Python is a programming language"
words = sentence.split()

longest = words[0]

for word in words:
    if len(word) > len(longest):
        longest = word

print("Longest word:", longest)
# Out:
# Longest word: programming

# %%
##print("\nQuestion 16: Remove all punctuation from 'Hello, World! How are you?'")

# %%
##print("\nQuestion 17: Check if string starts with 'Python'")
sentence="Python is a programming language"
word=sentence.startswith("Python")
print(word)
# Out:
# True

# %%
##print("\nQuestion 18: Find the index of first occurrence of 'o' in 'Hello World'")
first='Hello World'
first_occurance=first.index('o')
print(first_occurance)
# Out:
# Question 18: Find the index of first occurrence of 'o' in 'Hello World'
# 4

# %%
##print("\nQuestion 19: Split string 'apple,banana,orange' by comma")
text='apple,banana,orange'
result=text.split(",")
print(result)
# Out:
# ['apple', 'banana', 'orange']

# %%
##print("\nQuestion 20: Join list ['Python', 'is', 'awesome'] with spaces")
lists=['Python', 'is', 'awesome']
strings=' '.join(lists)
print(strings)
print(type(strings))
# Out:
# Python is awesome
# <class 'str'>

# %%
##print("\nQuestion 21: Check if string contains only digits: '12345'")

# %%
##print("\nQuestion 24: Find all positions of 'a' in 'banana'")
fruit="banana"
for i in range(len(fruit)):
    if fruit[i] == "a":
        print(i)
# Out:
# 1
# 3
# 5

# %%
##print("\nQuestion 25: Remove leading and trailing whitespace from '  Hello World  '")
two_sentence= "  Hello World  "
print(two_sentence)
two_sentence_removed=two_sentence.strip()
print(two_sentence_removed)
# Out:
#   Hello World
# Hello World

# %%
##print("\nQuestion 26: Check if string ends with 'ing': 'programming'")
firstly='programming'
secondly=firstly.endswith('ing')
print(secondly)
# Out:
# True

# %%
##print("\nQuestion 27: Replace first occurrence of 'o' with '0' in 'Hello World'")
word='Hello World'
first_word=word.replace('o','0',1)
print(first_word)
# Out:
# Hell0 World
