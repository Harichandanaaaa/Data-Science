# %% [markdown]
# we basically use (re) for extracting the pattrens like email,contact number, pancard, gstin.

# %% [markdown]
# # re.search
# This is used to search the given pettern in the enire string.

# %%
import re
# Search is used to search the given pettern in the enire string.
text="This is my contact number 8985834576"
re.search("is",text)
# Out:
# <re.Match object; span=(2, 4), match='is'>

# %%
text="This is my contact number 8985834576"
re.search("my",text)
# Out:
# <re.Match object; span=(8, 10), match='my'>

# %%
text="This is my contact number 8985834576"
re.search("My",text)
# Since i gave M instead of m it gives no output

# %% [markdown]
# # re.match
# This only gives at the beginning of the string like just This not anything after the first word.

# %%
# Match...This only gives at the beginning of the string like just This not anything after the first word.
text2="This car is not mine"
re.match("This",text2)
# Out:
# <re.Match object; span=(0, 4), match='This'>

# %%
text2="This car is not mine"
re.match("this",text2)
# No match

# %%
text2="This car is not mine"
re.match("car",text2)
#no output since car is not the first word.

# %% [markdown]
# # re.findall
# This findall function is used find the given pettern even is it exists multiple times in the string.

# %%
text3="This cat was not aware of the lies told by another cat.cat walks like catwalk"
re.findall("cat",text3)
# Out:
# ['cat', 'cat', 'cat', 'cat']

# %%
text3="This cat was not aware of the lies told by another cat."
re.findall("cat",text3)
# Out:
# ['cat', 'cat']

# %%
text3="This cat was not aware of the lies told by another cat, the cat walks like catwalk"
re.findall("the",text3)
# Out:
# ['the', 'the', 'the']

# %%
text4="I graduated in the year 2025"
re.findall('[0-9]',text4)
# Out:
# ['2', '0', '2', '5']

# %%
text5="This world is going to destroy one day"
re.findall("[aeiou]",text5)
# Out:
# ['i', 'o', 'i', 'o', 'i', 'o', 'e', 'o', 'o', 'e', 'a']

# %% [markdown]
# # re.sub
# This sub function is used for substituting or replacing the text.
# syntax: re.sub(pattern,replacement,string)

# %%
text6="My contact number is 567489320."
re.sub(r"\d+","*****",text6)
# Out:
# 'My contact number is *****.'

# %%
text6="I graduated in 2025"
re.sub(r"\d+","the year of 2025",text6)
# Out:
# 'I graduated in the year of 2025'

# %% [markdown]
# 1. Extract all twitter handles from following text.Also it contains only alpha numeric characters i.e. A-Z a-z , o to 9 and underscore _

# %%
text = '''
Follow our leader Elon musk on twitter here: https://twitter.com/elonmusk,Also here are leading influencers 
for tesla related news,
https://twitter.com/teslarati
https://twitter.com/dummy_tesla
https://twitter.com/dummy_2_tesla
'''
pattern = 'https://twitter.com/([a-zA-Z0-9_]+)' # todo: type your regex here

re.findall(pattern, text)
# Out:
# ['elonmusk', 'teslarati', 'dummy_tesla', 'dummy_2_tesla']

# %% [markdown]
# 2. Extract Concentration Risk Types. It will be a text that appears after "Concentration Risk:", In below example, your regex should extract these two strings

# %%
text = '''
Concentration of Risk: Credit Risk
Financial instruments that potentially subject us to a concentration of credit risk consist of cash, cash equivalents, marketable securities,
restricted cash, accounts receivable, convertible note hedges, and interest rate swaps. Our cash balances are primarily invested in money market funds
or on deposit at high credit quality financial institutions in the U.S. These deposits are typically in excess of insured limits. As of September 30, 2021
and December 31, 2020, no entity represented 10% or more of our total accounts receivable balance. The risk of concentration for our convertible note
hedges and interest rate swaps is mitigated by transacting with several highly-rated multinational banks.
Concentration of Risk: Supply Risk
We are dependent on our suppliers, including single source suppliers, and the inability of these suppliers to deliver necessary components of our
products in a timely manner at prices, quality levels and volumes acceptable to us, or our inability to efficiently manage these components from these
suppliers, could have a material adverse effect on our business, prospects, financial condition and operating results.
'''
pattern = 'Concentration of Risk: ([^\n]*)'

re.findall(pattern, text)
# Out:
# ['Credit Risk', 'Supply Risk']

# %% [markdown]
# 3. Companies in europe reports their financial numbers of semi annual basis and you can have a document like this. To exatract quarterly and semin annual period you can use a regex as shown below

# %%
text = '''
Tesla's gross cost of operating lease vehicles in FY2021 Q1 was $4.85 billion.
BMW's gross cost of operating vehicles in FY2021 S1 was $8 billion.
'''

pattern = r"FY(\d{4} (?:Q[1-4]|S[1-4]))"
matches = re.findall(pattern, text)
matches
# Out:
# ['2021 Q1', '2021 S1']

# %% [markdown]
# # Extracting
# pancard,mobile number,email,dates,currency,bank account,currency ammount, gstin

# %%
string="This is my mobile number 5678347647 and Pan card number: QWERT123Y."
re.findall(r"[A-Z]{5}[0-9]{3}[A-Z]",string)
# Out:
# ['QWERT123Y']

# %%
string1="The contact number is 5657478744."
re.findall(r"[0-9]",string1)
# Out:
# ['5', '6', '5', '7', '4', '7', '8', '7', '4', '4']

# %%
string2 = """
On 04/04/2025, Ms. Anjali Verma received a credit of Rs. 1,20,000 in her HDFC account 
(A/C No: 50100233456789) via NEFT (UTR No: HDFCNEFT0425TXN00123).

The amount was transferred from XYZ Pvt Ltd (GSTIN: 27AAACX1234B1Z9), 
as part of her consultancy payment. Her PAN number is APLPV2345C.

Anjali made an online purchase worth Rs. 8,499 on Myntra 
(Order ID: MYN/ORD/20250403/1147) and paid Rs. 2,300 for utilities through Google Pay 
(Txn ID: GPay2025040312345).

For inquiries, she can be contacted at +91-9988776655 
or emailed at anjali.verma84@gmail.com.

Her office contact number is 080-23456789.

The company also sent an invoice 
(Invoice No: INV/2025/XYZ-004) dated 03/04/2025.

She logged into the company portal using her ID: EMP-2025-0098.
"""
# Extracting the Pan Card Number
pan_number=re.findall(r"[A-Z]{5}[0-9]{4}[A-Z]",string2)
pan_number

#Extracting contact number
contact_number=re.findall(r"(?:\+91[- ]?)\d{10}|\d{3}[- ]\d{8}",string2)
contact_number

#Extracting Email 
email=re.findall(r"[a-z0-9.]+@[a-z]{5}.[a-z]{3}",string2)
email

#Extracting Dates
dates=re.findall(r"\d{2}/\d{2}/\d{4}",string2)
dates

#Extracting Account Number
account_num=re.findall(r"\d{14}",string2)
account_num

#Extracting Amount
amount=re.findall(r"Rs\.?\s?[\d,]+",string2)
amount
# Out:
# ['Rs. 1,20,000', 'Rs. 8,499', 'Rs. 2,300']
