# %%
for i in range(10):
    if i%2==0:
        continue #skips the values which are satisfiying the conditions
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
numbers = [12, 15, 21, 25, 30, 35, 40]
found_number = None
for num in numbers:  
    if num%7==0:
        found_number=num
        print(found_number) 
        break   
if found_number:
    print(f"The number {found_number} is divisible by 7.")  
else:
    print("None of the given list numbers are not divisible")
# Out:
# 21
# The number 21 is divisible by 7.

# %%
for i in range(5):
    if i == 3:
        # Maybe handle 3 specially later?
        pass # For now, do nothing different for 3
    else:
        print(i)

pass # You can put pass anywhere a statement is needed

print("Finished example with pass")
# Out:
# 0
# 1
# 2
# 4
# Finished example with pass

# %%
for i in  range(10):
    if i ==5 or i==8 or i==9:
        pass
    else:
        print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7

# %%
for i in range(10):
    if i in (3,1,7):
        pass
    else:
        print(i)
# Out:
# 0
# 2
# 4
# 5
# 6
# 8
# 9

# %%
items=["book","Pen","Slate"]
items_find="Sketch"
for item in items:
    if item==items:
        break
else:
    print(f"The {items_find} not found.")
# Out:
# The Sketch not found.

# %%
class Student:
    def __init__(self,name,roll_number,grade):
        self.name=name
        self.roll_number=roll_number
        self.grade=grade
        self.subjects=[]
        self.marks={}
        
    def add_subject(self,subject_name):
        if subject_name not in self.subjects:
            self.subjects.append(subject_name)
            print(f"Subject {subject_name} added for {self.name}")
        else:
            print(f"{self.name} is already enrolled is {subject_name}")
